# %% [markdown]
# <a href="https://colab.research.google.com/github/anumit-web/ML-Masterlist-2024/blob/main/scikit-learn/scikit-learn_Masterlist_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# scikit learn

# %% [markdown]
# iris dataset

# %% [markdown]
# https://archive.ics.uci.edu/dataset/53/iris

# %%
import seaborn as sns
iris_df = sns.load_dataset('iris')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris_df.info()

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# comment out because already installed
# ! pip install skimpy

# %%
from skimpy import skim
skim (iris_df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 150    │ │ float64     │ 4     │                                                          │
# │ │ Number of columns │ 5      │ │ string      │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name       ┃ NA   ┃ NA %   ┃ mean     ┃ sd        ┃ p0    ┃ p25   ┃ p50    ┃ p75  ┃ p100  ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━┩  │
# │ │ sepal_length      │    0 │      0 │    5.843 │    0.8281 │   4.3 │   5.1 │    5.8 │  6.4 │   7.9 │ ▃▇▇▇▅▂  │  │
# │ │ sepal_width       │    0 │      0 │    3.057 │    0.4359 │     2 │   2.8 │      3 │  3.3 │   4.4 │ ▁▇▇▇▂▁  │  │
# │ │ petal_length      │    0 │      0 │    3.758 │     1.765 │     1 │   1.6 │   4.35 │  5.1 │   6.9 │ ▇ ▂▇▆▂  │  │
# │ │ petal_width       │    0 │      0 │    1.199 │    0.7622 │   0.1 │   0.3 │    1.3 │  1.8 │   2.5 │ ▇ ▂▆▅▃  │  │
# │ └───────────────────┴──────┴────────┴──────────┴───────────┴───────┴───────┴────────┴──────┴───────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ species                   │       0 │          0 │                            1 │                      150 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
# comment out because already installed
# ! pip install summarytools

# %%
from summarytools import dfSummary

dfSummary(iris_df)
# Out:
# <style type="text/css">
# #T_22a0c thead>tr>th {
#   text-align: left;
# }
# #T_22a0c_row0_col0, #T_22a0c_row1_col0, #T_22a0c_row2_col0, #T_22a0c_row3_col0, #T_22a0c_row4_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_22a0c_row0_col1, #T_22a0c_row1_col1, #T_22a0c_row2_col1, #T_22a0c_row3_col1, #T_22a0c_row4_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_22a0c_row0_col2, #T_22a0c_row1_col2, #T_22a0c_row2_col2, #T_22a0c_row3_col2, #T_22a0c_row4_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_22a0c_row0_col3, #T_22a0c_row1_col3, #T_22a0c_row2_col3, #T_22a0c_row3_col3, #T_22a0c_row4_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_22a0c_row0_col4, #T_22a0c_row1_col4, #T_22a0c_row2_col4, #T_22a0c_row3_col4, #T_22a0c_row4_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_22a0c_row0_col5, #T_22a0c_row1_col5, #T_22a0c_row2_col5, #T_22a0c_row3_col5, #T_22a0c_row4_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_22a0c" class="dataframe">
#   <caption><strong>Data Frame Summary</strong><br>iris_df<br>Dimensions: 150 x 5<br>Duplicates: 1</caption>
#   <thead>
#     <tr>
#       <th id="T_22a0c_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_22a0c_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_22a0c_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_22a0c_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_22a0c_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_22a0c_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_22a0c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_22a0c_row0_col1" class="data row0 col1" ><strong>sepal_length</strong><br>[float64]</td>
#       <td id="T_22a0c_row0_col2" class="data row0 col2" >Mean (sd) : 5.8 (0.8)<br>min < med < max:<br>4.3 < 5.8 < 7.9<br>IQR (CV) : 1.3 (7.1)</td>
#       <td id="T_22a0c_row0_col3" class="data row0 col3" >35 distinct values</td>
#       <td id="T_22a0c_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_22a0c_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_22a0c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_22a0c_row1_col1" class="data row1 col1" ><strong>sepal_width</strong><br>[float64]</td>
#       <td id="T_22a0c_row1_col2" class="data row1 col2" >Mean (sd) : 3.1 (0.4)<br>min < med < max:<br>2.0 < 3.0 < 4.4<br>IQR (CV) : 0.5 (7.0)</td>
#       <td id="T_22a0c_row1_col3" class="data row1 col3" >23 distinct values</td>
#       <td id="T_22a0c_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_22a0c_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_22a0c_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_22a0c_row2_col1" class="data row2 col1" ><strong>petal_length</strong><br>[float64]</td>
#       <td id="T_22a0c_row2_col2" class="data row2 col2" >Mean (sd) : 3.8 (1.8)<br>min < med < max:<br>1.0 < 4.3 < 6.9<br>IQR (CV) : 3.5 (2.1)</td>
#       <td id="T_22a0c_row2_col3" class="data row2 col3" >43 distinct values</td>
#       <td id="T_22a0c_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_22a0c_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_22a0c_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_22a0c_row3_col1" class="data row3 col1" ><strong>petal_width</strong><br>[float64]</td>
#       <td id="T_22a0c_row3_col2" class="data row3 col2" >Mean (sd) : 1.2 (0.8)<br>min < med < max:<br>0.1 < 1.3 < 2.5<br>IQR (CV) : 1.5 (1.6)</td>
#       <td id="T_22a0c_row3_col3" class="data row3 col3" >22 distinct values</td>
#       <td id="T_22a0c_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_22a0c_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_22a0c_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_22a0c_row4_col1" class="data row4 col1" ><strong>species</strong><br>[object]</td>
#       <td id="T_22a0c_row4_col2" class="data row4 col2" >1. setosa<br>2. versicolor<br>3. virginica</td>
#       <td id="T_22a0c_row4_col3" class="data row4 col3" >50 (33.3%)<br>50 (33.3%)<br>50 (33.3%)</td>
#       <td id="T_22a0c_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_22a0c_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>
