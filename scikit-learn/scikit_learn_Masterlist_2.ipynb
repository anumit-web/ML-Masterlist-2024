# %% [markdown]
# # Pandas testing

# %% [markdown]
# code location =
#
# https://github.com/anumit-web/Pandas-tutorial-3/

# %% [markdown]
# code reference =
#
# https://www.datacamp.com/tutorial/pandas-read-csv
#
# https://blog.dailydoseofds.com/p/you-will-never-use-pandas-describe
#
# https://chatgpt.com/
#
# https://www.meta.ai/

# %% [markdown]
# <a id="cell2">Cell 2</a>

# %% [markdown]
# <a id="my-cell"></a>
# # My Important Cell

# %%
print ("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
# !wget https://github.com/datasciencedojo/datasets/blob/master/titanic.csv

# %% [markdown]
# # titanic csv
# https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
#
# Use titanic data from Stanford university

# %%
# !wget https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Out:
# --2024-08-11 12:55:19--  https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv
# Resolving web.stanford.edu (web.stanford.edu)... 171.67.215.200, 2607:f6d0:0:925a::ab43:d7c8
# Connecting to web.stanford.edu (web.stanford.edu)|171.67.215.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44225 (43K) [text/csv]
# Saving to: ‘titanic.csv.8’
#
# titanic.csv.8       100%[===================>]  43.19K  --.-KB/s    in 0.1s
#
# 2024-08-11 12:55:19 (304 KB/s) - ‘titanic.csv.8’ saved [44225/44225]

# %%
df = pd.read_csv('titanic.csv')

print(df.to_string())
# Out:
#      Survived  Pclass                                                                               Name     Sex    Age  Siblings/Spouses Aboard  Parents/Children Aboard      Fare
# 0           0       3                                                             Mr. Owen Harris Braund    male  22.00                        1                        0    7.2500
# 1           1       1                                 Mrs. John Bradley (Florence Briggs Thayer) Cumings  female  38.00                        1                        0   71.2833
# 2           1       3                                                              Miss. Laina Heikkinen  female  26.00                        0                        0    7.9250
# 3           1       1                                        Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.00                        1                        0   53.1000
# ...

# %% [markdown]
# # pokemon data

# %% [markdown]
# # The Universirty of Arizona
# # Department of Computer Science
#
# CSc 120: Pokemon data analysis
#
# https://www2.cs.arizona.edu/classes/cs120/fall17/ASSIGNMENTS/assg02/pokemon.html

# %%
df2 = pd.read_csv('https://www2.cs.arizona.edu/classes/cs120/fall17/ASSIGNMENTS/assg02/Pokemon.csv')

# %%
print(df2)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# head
#
# tail
#
# information
#
# describe

# %%
df2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df2.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df2.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
! pip install skimpy

# %%
from skimpy import skim
skim (df2)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 800    │ │ int64       │ 9     │                                                          │
# │ │ Number of columns │ 13     │ │ string      │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ bool        │ 1     │                                                          │
# ...

# %%
! pip install summarytools

# %%
from summarytools import dfSummary

dfSummary(df2)
# Out:
# <style type="text/css">
# #T_52f73 thead>tr>th {
#   text-align: left;
# }
# #T_52f73_row0_col0, #T_52f73_row1_col0, #T_52f73_row2_col0, #T_52f73_row3_col0, #T_52f73_row4_col0, #T_52f73_row5_col0, #T_52f73_row6_col0, #T_52f73_row7_col0, #T_52f73_row8_col0, #T_52f73_row9_col0, #T_52f73_row10_col0, #T_52f73_row11_col0, #T_52f73_row12_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_52f73_row0_col1, #T_52f73_row1_col1, #T_52f73_row2_col1, #T_52f73_row3_col1, #T_52f73_row4_col1, #T_52f73_row5_col1, #T_52f73_row6_col1, #T_52f73_row7_col1, #T_52f73_row8_col1, #T_52f73_row9_col1, #T_52f73_row10_col1, #T_52f73_row11_col1, #T_52f73_row12_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# ...

# %%
max_value = df2['Total'].max()
print(max_value)
# Out:
# 780

# %%
#empty

# %% [markdown]
# Pandas DataFrame Group By, Mean, Sort by Average in Descending Order, and Print First Row

# %%
average_total = df2.groupby('Type 1')['Total'].mean()
print(average_total)
# Out:
# Type 1
# Bug         378.927536
# Dark        445.741935
# Dragon      550.531250
# Electric    443.409091
# Fairy       413.176471
# Fighting    416.444444
# Fire        458.076923
# Flying      485.000000
# Ghost       439.562500
# Grass       421.142857
# Ground      437.500000
# Ice         433.458333
# Normal      401.683673
# Poison      399.142857
# Psychic     475.947368
# Rock        453.750000
# Steel       487.703704
# Water       430.455357
# Name: Total, dtype: float64

# %%
grouped = df2.groupby('Type 1')
mean_values = grouped['Total'].mean()
sorted_mean_values = mean_values.sort_values(ascending=False)
print(sorted_mean_values)
# Out:
# Type 1
# Dragon      550.531250
# Steel       487.703704
# Flying      485.000000
# Psychic     475.947368
# Fire        458.076923
# Rock        453.750000
# Dark        445.741935
# Electric    443.409091
# Ghost       439.562500
# Ground      437.500000
# Ice         433.458333
# Water       430.455357
# Grass       421.142857
# Fighting    416.444444
# Fairy       413.176471
# Normal      401.683673
# Poison      399.142857
# Bug         378.927536
# Name: Total, dtype: float64

# %%
print(sorted_mean_values.head(1))
# Out:
# Type 1
# Dragon    550.53125
# Name: Total, dtype: float64

# %%
print(sorted_mean_values.index[0])
# Out:
# Dragon

# %% [markdown]
# *[jump to code cell 2](#cell2)

# %% [markdown]
# [Top](#)

# %% [markdown]
# [<i class="fa fa-arrow-up" aria-hidden="true"></i> Back to Top](#)

# %% [markdown]
# [Go to Data Analysis Section](#data-analysis-section)
